# %%
import pandas as pd

# %%
df = pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df = pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df.head()

# %%
df = pd.read_csv("Car details v3.csv")
df.head()

# %%
df = pd.read_csv("car details v4.csv")
df.head()

# %%
print(df.dtypes)
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
print(f"Number of Row : {df.shape[0]}\nNumber of Columns : {df.shape[1]}")
# Out:
# Number of Row : 301
# Number of Columns : 9

# %%
df.info()

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df["Age"] = 2019 - df["Year"]

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Age
# 0        Dealer       Manual      0    5
# 1        Dealer       Manual      0    6
# 2        Dealer       Manual      0    2
# 3        Dealer       Manual      0    8
# 4        Dealer       Manual      0    5
# ..          ...          ...    ...  ...
# 296      Dealer       Manual      0    3
# 297      Dealer       Manual      0    4
# 298      Dealer       Manual      0   10
# 299      Dealer       Manual      0    2
# 300      Dealer       Manual      0    3
#
# [301 rows x 10 columns]

# %%
df.drop("Year" , axis = 1 , inplace = True)
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz           3.35           5.59       27000    Petrol      Dealer
# 1        sx4           4.75           9.54       43000    Diesel      Dealer
# 2       ciaz           7.25           9.85        6900    Petrol      Dealer
# 3    wagon r           2.85           4.15        5200    Petrol      Dealer
# 4      swift           4.60           6.87       42450    Diesel      Dealer
# ..       ...            ...            ...         ...       ...         ...
# 296     city           9.50          11.60       33988    Diesel      Dealer
# 297     brio           4.00           5.90       60000    Petrol      Dealer
# 298     city           3.35          11.00       87934    Petrol      Dealer
# 299     city          11.50          12.50        9000    Diesel      Dealer
# 300     brio           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0    5
# 1         Manual      0    6
# 2         Manual      0    2
# 3         Manual      0    8
# 4         Manual      0    5
# ..           ...    ...  ...
# 296       Manual      0    3
# 297       Manual      0    4
# 298       Manual      0   10
# 299       Manual      0    2
# 300       Manual      0    3
#
# [301 rows x 9 columns]

# %%
import matplotlib as pyplt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ["Fuel_Type","Seller_Type","Transmission","Owner"]
for i in columns:
    fig = plt.figure(figsize =[5,4])
    sns.countplot(x=i, data=df)
    plt.xlabel(i)
    plt.show()

# %%
columns = ["Selling_Price","Present_Price","Kms_Driven","Age"]
for i in columns:
    fig = plt.figure(figsize =[5,4])
    sns.boxplot(x=i, data=df)
    plt.xlabel(i)
    plt.show()

# %%
numeric_data = df.select_dtypes(include=["number"])
numeric_data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age
# 0             3.35           5.59       27000      0    5
# 1             4.75           9.54       43000      0    6
# 2             7.25           9.85        6900      0    2
# 3             2.85           4.15        5200      0    8
# 4             4.60           6.87       42450      0    5
# ..             ...            ...         ...    ...  ...
# 296           9.50          11.60       33988      0    3
# 297           4.00           5.90       60000      0    4
# 298           3.35          11.00       87934      0   10
# 299          11.50          12.50        9000      0    2
# 300           5.30           5.90        5464      0    3
#
# [301 rows x 5 columns]

# %%
numeric_data.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner       Age
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# Age                -0.236141       0.047584    0.524342  0.182104  1.000000

# %%
print(pd.unique(df["Fuel_Type"]))
print(pd.unique(df["Seller_Type"]))
print(pd.unique(df["Transmission"]))
print(pd.unique(df["Owner"]))
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df["Fuel_Type"].replace({"Petrol":2 , "Diesel":3 , "CNG":4} , inplace=True)
df["Seller_Type"].replace({"Dealer":2 , "Individual":3 } , inplace=True)
df["Transmission"].replace({"Manual":2 , "Automatic":3 } , inplace=True)
df
# Out:
# /tmp/ipykernel_28824/2326949946.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fuel_Type"].replace({"Petrol":2 , "Diesel":3 , "CNG":4} , inplace=True)
# /tmp/ipykernel_28824/2326949946.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Fuel_Type"].replace({"Petrol":2 , "Diesel":3 , "CNG":4} , inplace=True)
# /tmp/ipykernel_28824/2326949946.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Seller_Type"].replace({"Dealer":2 , "Individual":3 } , inplace=True)
# /tmp/ipykernel_28824/2326949946.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Seller_Type"].replace({"Dealer":2 , "Individual":3 } , inplace=True)
# /tmp/ipykernel_28824/2326949946.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Transmission"].replace({"Manual":2 , "Automatic":3 } , inplace=True)
# /tmp/ipykernel_28824/2326949946.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Transmission"].replace({"Manual":2 , "Automatic":3 } , inplace=True)
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz           3.35           5.59       27000          2
# 1        sx4           4.75           9.54       43000          3
# 2       ciaz           7.25           9.85        6900          2
# 3    wagon r           2.85           4.15        5200          2
# 4      swift           4.60           6.87       42450          3
# ..       ...            ...            ...         ...        ...
# 296     city           9.50          11.60       33988          3
# 297     brio           4.00           5.90       60000          2
# 298     city           3.35          11.00       87934          2
# 299     city          11.50          12.50        9000          3
# 300     brio           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner  Age
# 0              2             2      0    5
# 1              2             2      0    6
# 2              2             2      0    2
# 3              2             2      0    8
# 4              2             2      0    5
# ..           ...           ...    ...  ...
# 296            2             2      0    3
# 297            2             2      0    4
# 298            2             2      0   10
# 299            2             2      0    2
# 300            2             2      0    3
#
# [301 rows x 9 columns]

# %%
df.drop(labels="Car_Name" , axis =1 , inplace = True)
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# 3               2      0    8
# 4               2      0    5
# ..            ...    ...  ...
# 296             2      0    3
# 297             2      0    4
# 298             2      0   10
# 299             2      0    2
# 300             2      0    3
#
# [301 rows x 8 columns]

# %%
x = df.drop ("Selling_Price" , axis =1)
y = df["Selling_Price"]

# %%
x
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          3            2             2      0
# 297           5.90       60000          2            2             2      0
# 298          11.00       87934          2            2             2      0
# 299          12.50        9000          3            2             2      0
# 300           5.90        5464          2            2             2      0
#
#      Age
# 0      5
# 1      6
# 2      2
# 3      8
# 4      5
# ..   ...
# 296    3
# 297    4
# 298   10
# 299    2
# 300    3
#
# [301 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
x_train,x_test ,y_train, y_test = train_test_split(x ,y,test_size = 0.2, random_state =1)
print("x_train: ",x_train.shape)
print("x_test: ",x_test.shape)
print("y_test: ",y_test.shape)
print("y_train: ",y_train.shape)
# Out:
# x_train:  (240, 7)
# x_test:  (61, 7)
# y_test:  (61,)
# y_train:  (240,)

# %%
print("Training Features:", x_train.columns)
# Out:
# Training Features: Index(['Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type',
#        'Transmission', 'Owner', 'Age'],
#       dtype='object')

# %%
Model = LinearRegression()
Model.fit (x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = Model.predict(x_test)

# %%
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error: " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("R2 Score: ", metrics.r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error:  1.153004591615892
# Mean Squared Error:  3.2876460857158407
# Root Mean Squared Error:  1.8131867211392876
# R2 Score:  0.8484549412090379

# %%
import numpy as np

# %%
import joblib
joblib.dump(Model, "vehicle_price_predictor.pkl")
# Out:
# ['vehicle_price_predictor.pkl']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing
